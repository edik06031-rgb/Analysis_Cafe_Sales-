# %% [markdown]
# <a href="https://colab.research.google.com/github/edik06031-rgb/Analysis_Cafe_Sales-/blob/main/notebook/simple_predict_olis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Teil 3. Python: Einfache Prognosen und Empfehlungen
